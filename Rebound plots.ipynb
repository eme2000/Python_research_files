# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
follow_without = pd.read_csv('follow_without.all', sep=" ", header = 0, names = ['Time', 'ObjectNum', 'SemiAxis', 'Ecc', 'Inc', 'Mass'], skipinitialspace=True)

m2 = []
m3 = []
m4 = []
t2 = []
t3 = []
e2 = []
e3 = []
a2 = []
a3 = []

for x in range(len(follow.ObjectNum)):
    if follow_without.ObjectNum[x] == 2:
        b2_m.append(follow_without.Mass[x])
        t2.append(follow_without.Time[x])
        e2.append(follow_without.Ecc[x])
        a2.append(follow_without.SemiAxis[x])
    elif follow.ObjectNum[x] == 3:
        b3_m.append(follow_without.Mass[x])
        t3.append(follow_without.Time[x])
        e3.append(follow_without.Ecc[x])
        a3.append(follow_without.SemiAxis[x])

# %%
plt.scatter(t2, b2_m, facecolors='none', s = 4, color = 'slateblue') #earth
plt.scatter(t3, b3_m, facecolors='none', s = 4, color = 'red') #asteroid
plt.xlabel('Time',fontsize=13)
plt.ylabel('Mass',fontsize=13)
# Out:
# Text(0, 0.5, 'Mass')

# %%
plt.scatter(t2, e2, facecolors='none', s = 4, color = 'slateblue') #earth 
plt.scatter(t3, e3, facecolors='none', s = 4, color = 'red') #asteroid
plt.xlabel('Time',fontsize=13)
plt.ylabel('Eccentricity',fontsize=13)
# Out:
# Text(0, 0.5, 'Eccentricity')

# %%
plt.scatter(t2, a2, facecolors='none', s = 4, color = 'slateblue') #earth 
plt.scatter(t3, a3, facecolors='none', s = 4, color = 'red') #asteroid
plt.xlabel('Time',fontsize=13)
plt.ylabel('Semi-Major Axis',fontsize=13)
# Out:
# Text(0, 0.5, 'Semi-Major Axis')

# %%
follow_with = pd.read_csv('follow_with.all', sep=" ", header = 0, names = ['Time', 'ObjectNum', 'SemiAxis', 'Ecc', 'Inc', 'Mass'], skipinitialspace=True)

b2_m = []
b3_m = []
t2 = []
t3 = []
e2 = []
e3 = []
a2 = []
a3 = []

for x in range(len(follow_with.ObjectNum)):
    if follow_with.ObjectNum[x] == 2:
        b2_m.append(follow_with.Inc[x])
        t2.append(follow_with.Time[x])
        e2.append(follow_with.Ecc[x])
        a2.append(follow_with.SemiAxis[x])
    elif follow_with.ObjectNum[x] == 3:
        b3_m.append(follow_with.Inc[x])
        t3.append(follow_with.Time[x])
        e3.append(follow_with.Ecc[x])
        a3.append(follow_with.SemiAxis[x])

# %%
plt.scatter(t2, b2_m, facecolors='none', s = 4, color = 'slateblue') #earth
plt.scatter(t3, b3_m, facecolors='none', s = 4, color = 'red') #asteroid
plt.xlabel('Time',fontsize=13)
plt.ylabel('Inclination Angle',fontsize=13)
# Out:
# Text(0, 0.5, 'Inclination Angle')

# %%
plt.scatter(t2, a2, facecolors='none', s = 4, color = 'slateblue') #earth 
plt.scatter(t3, a3, facecolors='none', s = 4, color = 'red') #asteroid
plt.xlabel('Time (Myr)',fontsize=13)
plt.ylabel('Semi-Major Axis (AU)',fontsize=13)
# Out:
# Text(0, 0.5, 'Semi-Major Axis (AU)')
